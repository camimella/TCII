# %% [markdown]
# # Trabajo semanal 5

# %% [markdown]
# ![TS5_1.jpg](attachment:TS5_1.jpg)

# %% [markdown]
# ![TS5_2.jpg](attachment:TS5_2.jpg)

# %% [markdown]
# ![TS5_3.jpg](attachment:TS5_3.jpg)
