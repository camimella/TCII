# %% [markdown]
# # Trabajo Práctico de Laboratorio 1
#
# ## Integrantes:
#
# Contreras, Nahuel
# Mella, Camila
# Nogales, Mirta
# Pereira, Francisco
# Yañez, Pedro
#
# ### Teoría de Circuitos II - R4001

# %% [markdown]
# ### Objetivos
# - A partir de un plantilla circuital, analizar, simular, implementar y medir un circuito que responda a dicha plantilla.
# - Consolidar los conceptos de teoría moderna de filtrado mediante la implementación circuital.
# - Medir las partes de función transferencia con osciloscopio de un filtro analógico con frecuencias menores a 100 kHz.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Parte l

# %% [markdown]
# #### Diseño del circuito activo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![TP_1.jpg](attachment:TP_1.jpg)

# %% [markdown]
# ![TP_2.jpg](attachment:TP_2.jpg)

# %% [markdown]
# ![TP_3.jpg](attachment:TP_3.jpg)

# %% [markdown]
# #### Simulación del circuito activo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Como podemos apreciar en las simulaciones, el diseño del filtro pasa altos cumple con las especificaciones pedidas

# %% [markdown]
# ### Parte ll

# %% [markdown]
# #### MODULO

# %% [markdown]
# 1. Compute el cociente de tensiones entre la tensión de entrada y la de salida. Asegúrese de utilizar la misma unidad
#
# 2. Aplique el $20log(\frac{Vpo}{Vpi})$ para tener el módulo de la transferencia de tensión en dB

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# 3. Mediante análisis o simulación (numérica o circuital) obtenga el valor de transferencia de tensión en dB para las frecuencias de medición

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Grafique el módulo de la transferencia de tensión medida y simulada en función de la frecuencia. Utilice un gráfico de puntos dispersos (ya que son mediciones puntuales)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Discuta la morfología observada en la medición y  las diferencias observadas con la simulación

# %% [markdown]
# Vemos que el módulo de la transferencia es muy parecido al simulado en LTSpice. Hay pequeñas diferencias en la banda de transición que pueden ser atribuidas a las diferencias en la medición real y la simulación ideal. Además, siempre está el factor del error humano al realizar la medición.

# %% [markdown]
# #### RETARDO DE GRUPO

# %% [markdown]
# 1. Mediante análisis o simulación (numérica o circuital) obtenga el valor del retardo de grupo para cada valor de la frecuencia de medición

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Grafique el retardo medido y simulado en función de la frecuencia. Utilice un gráfico de puntos dispersos (ya que son mediciones puntuales)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Discuta la morfología observada en la medición y  las diferencias observadas con la simulación

# %% [markdown]
# Vemos que el retardo de grupo medido es mucho mayor al simulado en LTSpice.
# Podemos atribuir estas variaciones a:
# - Diferencias entre simulación real e ideal
# - Error humano en la medición realizada
# - Dispersión respecto del valor medido debido a la utilización de un osciloscopio para la obtención de las mediciones

# %% [markdown]
# #### FASE

# %% [markdown]
# 1. En función de la topología circuital y de la función transferencia teórica, identifique la fase en continua

# %% [markdown]
# A partir del diagrama de polos y ceros, sabemos que tenemos dos polos complejos conjugados y 2 ceros en el origen. Para la condición de continua (w=0), podemos observar que la fase de los polos se cancelan, por lo que solo sobrevive el aporte de los ceros. Como son 2 y cada uno aporta 90° a la fase total, tenemos que para w=0 la fase vale 180°
# ![image.png](attachment:image.png)

# %% [markdown]
#  2. Para computar la fase se deberá integrar el retardo.

# %% [markdown]
# Se obtuvo los valores de la diferencia temporal y la frecuencia, pero hay errores a la hora de calcular la fase analiticamente

# %%
import scipy.signal as sig
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mediciones = 'TPL_mediciones.csv'
datos_mediciones = pd.read_csv(mediciones)

#INDEX
#f(KHz),|Vi|(V),|Vo|(mV),dT(useg)
freqs = datos_mediciones['f(KHz)'].to_numpy()*1000
T     = datos_mediciones['dT(useg)'].to_numpy()*1e-6

# %% [markdown]
# 3. Compute la fase medida para cada una de las mediciones

# %% [markdown]
# IDEM (2)

# %% [markdown]
# 4. Obtenga mediante análisis o simulación la fase de cada una de las mediciones

# %%
z,p,k = sig.cheb1ap(2, 1)
num_lp, den_lp = sig.zpk2tf(z,p,k)
num_hp, den_hp = sig.lp2hp(num_lp, den_lp)
sys = sig.TransferFunction(num_hp, den_hp)

f = np.logspace(-1, 2,10000)
w, mag, phase = sig.bode(sys,f)

fase_sim = np.zeros(15)

#normalizo valores medidos
"""
500  = 0.108696 -- index(w) = 120
1000 = 0.217391 -- index(w) = 1124
1100 = 0.239130 -- index(w) = 1262
1200 = 0.260870 -- index(w) = 1388
1300 = 0.282609 -- index(w) = 1504
2000 = 0.434783 -- index(w) = 2127
3000 = 0.652174 -- index(w) = 2714
4000 = 0.869565 -- index(w) = 3131
4600 = 1        -- index(w) = 3333
5000 = 1.086957 -- index(w) = 3454
6330 = 1.376087 -- index(w) = 3795
10k  = 2.173913 -- index(w) = 4457
20k  = 4.347826 -- index(w) = 5460
50k  = 10.86957 -- index(w) = 6787
100k = 21.73913 -- index(w) = 7790
"""
#busco el valor normalizado asociado al vector simulado y lo paso manualmente

fase_sim[0] = phase[120]
fase_sim[1] = phase[1124]
fase_sim[2] = phase[1262]
fase_sim[3] = phase[1388]
fase_sim[4] = phase[1504]
fase_sim[5] = phase[2127]
fase_sim[6] = phase[2714]
fase_sim[7] = phase[3131]
fase_sim[8] = phase[3333]
fase_sim[9] = phase[3454]
fase_sim[10] = phase[3795]
fase_sim[11] = phase[4457]
fase_sim[12] = phase[5460]
fase_sim[13] = phase[6787]
fase_sim[14] = phase[7790]

# %% [markdown]
# 5. Grafique la fase medida y simulada en función de la frecuencia. Utilice un gráfico de puntos dispersos (ya que son mediciones puntuales)

# %%
plt.plot(range(0,15),fase_sim,'o')

# %% [markdown]
# 6. Discuta la morfología observada en la medición y  las diferencias observadas con la simulación

# %% [markdown]
# Podemos notar que a gran escala respetamos la tangencial de la fase. Se evidencian algunas variaciones respecto de los valores simulados. Estas diferencias pueden atribuirse:
# - Diferencias entre simulación real e ideal
# - Error humano en la medición realizada
# - Dispersión respecto del valor medido debido a la utilización de un osciloscopio para la obtención de las mediciones
