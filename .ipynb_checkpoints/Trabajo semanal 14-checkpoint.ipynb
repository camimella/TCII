# %% [markdown]
# # Trabajo semanal 14

# %% [markdown]
# ![TS14_1.jpg](attachment:TS14_1.jpg)

# %% [markdown]
# ![TS14_2.jpg](attachment:TS14_2.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
