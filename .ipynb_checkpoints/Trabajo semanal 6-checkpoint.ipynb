# %% [markdown]
# # Trabajo semanal 6

# %% [markdown]
# ![TS6_1.jpg](attachment:TS6_1.jpg)

# %% [markdown]
# ![TS6_2-2.jpg](attachment:TS6_2-2.jpg)

# %% [markdown]
# #### Análisis comparativo entre las redes propuestas:

# %% [markdown]
# Mientras que el primer circuito se comporta como un pasa alto, al segundo se lo generalizó, de manera que a partir de la modificación de ciertos parámetros, se puedan conseguir distintos comportamientos. Para esto, se intercambiaron un par de resistencias por capacitores y uno de los capacitores por una resistencia, y se agregaron prealimentaciones de tensión.

# %% [markdown]
# #### Diagramas:

# %%
import matplotlib.pyplot as plt
from scipy import signal as sig
from splane import pretty_print_lti, analyze_sys

num = [1, 0, 0.11, 0]
den = [1, 2, 2, 1]

tf = sig.TransferFunction(num, den)
pretty_print_lti(tf)
    
plt.close('all')

analyze_sys(tf, 'TS6')
# Out:
# $\displaystyle \frac{s^3 + s \,\, 0.11 }{s^3 + s^2 \,\,   2 + s \,\,   2 +   1 }$

# %% [markdown]
# #### Simulación circuital

# %% [markdown]
# ![image.png](attachment:image.png)
