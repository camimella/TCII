# %% [markdown]
# # Trabajo semanal 12

# %% [markdown]
# ![TS12_1.jpg](attachment:TS12_1.jpg)

# %% [markdown]
# ![TS12_2.jpg](attachment:TS12_2.jpg)

# %% [markdown]
# ![TS12_3.jpg](attachment:TS12_3.jpg)

# %% [markdown]
# ![TS12_4.jpg](attachment:TS12_4.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
